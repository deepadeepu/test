# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("train.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train[(train['Age']>60)][['Sex']].count()
# Out:
# Sex    22
# dtype: int64

# %%
title=pd.DataFrame(train['Name'])
title=[i.split()[1] for i in train['Name']]

# %%
train['Title']=title

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr.
# 1      0          PC 17599  71.2833   C85        C   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.
# 3      0            113803  53.1000  C123        S   Mrs.
# ...

# %%
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'].fillna('S',inplace=True)

# %%
train.groupby(['Title'])['Age'].mean()
# Out:
# Title
# Billiard,       40.500000
# Capt.           70.000000
# Carlo,          29.000000
# Col.            58.000000
# Cruyssen,       47.000000
# Don.            40.000000
# Dr.             42.000000
# Gordon,         48.500000
# Impe,           25.333333
# Jonkheer.       38.000000
# Major.          48.500000
# Master.          4.574167
# Melkebeke,            NaN
# Messemaeker,    36.000000
# Miss.           21.846154
# Mlle.           24.000000
# Mme.            24.000000
# Mr.             32.389610
# Mrs.            36.182692
# Ms.             28.000000
# Mulder,         30.000000
# Pelsmaeker,     16.000000
# Planke,         21.666667
# Rev.            43.166667
# Shawah,         30.000000
# Steen,          28.000000
# Velde,          33.000000
# Walle,          28.000000
# der             61.000000
# the             33.000000
# y               20.666667
# Name: Age, dtype: float64

# %%
##na values in age by title
train.groupby(['Title'])['Age'].apply(lambda x: x.isnull().sum())
# Out:
# Title
# Billiard,         0
# Capt.             0
# Carlo,            0
# Col.              0
# Cruyssen,         0
# Don.              0
# Dr.               1
# Gordon,           0
# Impe,             0
# Jonkheer.         0
# Major.            0
# Master.           4
# Melkebeke,        1
# Messemaeker,      0
# Miss.            36
# Mlle.             0
# Mme.              0
# Mr.             117
# Mrs.             17
# Ms.               0
# Mulder,           0
# Pelsmaeker,       0
# Planke,           0
# Rev.              0
# Shawah,           0
# Steen,            0
# Velde,            0
# Walle,            0
# der               0
# the               0
# y                 1
# Name: Age, dtype: int64

# %%
train['Age'] = train.groupby(['Title'])['Age'].apply(lambda x: x.fillna(x.mean()))

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              1
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Title            0
# dtype: int64

# %%
train['Age'].isnull().sum()
# Out:
# 1

# %%
train['Age'].fillna(value=train['Age'].mean() , inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Title            0
# dtype: int64

# %%
train.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    37.557963
# 2    29.849488
# 3    26.277412
# Name: Age, dtype: float64

# %%
train.groupby('Pclass')['Survived'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
train['Cabin'].value_counts()
# Out:
# C23 C25 C27        4
# B96 B98            4
# G6                 4
# F33                3
# F2                 3
# D                  3
# C22 C26            3
# E101               3
# D17                2
# C78                2
# B58 B60            2
# E33                2
# B20                2
# C124               2
# C93                2
# C2                 2
# B22                2
# D35                2
# D33                2
# B57 B59 B63 B66    2
# C65                2
# B5                 2
# B35                2
# C68                2
# D26                2
# C52                2
# C125               2
# C123               2
# E8                 2
# B18                2
#                   ..
# E40                1
# C30                1
# E50                1
# B80                1
# B19                1
# B42                1
# F38                1
# C106               1
# A10                1
# D19                1
# D10 D12            1
# C103               1
# ...

# %%
train.groupby(['Pclass'])['Cabin'].apply(lambda x: x.isnull().sum())
# Out:
# Pclass
# 1     40
# 2    168
# 3    479
# Name: Cabin, dtype: int64

# %%
# Table of survival vs. sex
pd.crosstab(train["Cabin"],train["Pclass"])
# Out:
# Pclass  1  2  3
# Cabin
# A10     1  0  0
# A14     1  0  0
# A16     1  0  0
# A19     1  0  0
# A20     1  0  0
# A23     1  0  0
# A24     1  0  0
# A26     1  0  0
# A31     1  0  0
# A32     1  0  0
# A34     1  0  0
# A36     1  0  0
# A5      1  0  0
# A6      1  0  0
# A7      1  0  0
# B101    1  0  0
# B102    1  0  0
# B18     2  0  0
# B19     1  0  0
# B20     2  0  0
# B22     2  0  0
# B28     2  0  0
# B3      1  0  0
# B30     1  0  0
# B35     2  0  0
# B37     1  0  0
# B38     1  0  0
# B39     1  0  0
# B4      1  0  0
# B41     1  0  0
# ...    .. .. ..
# E12     1  0  0
# E121    0  0  2
# E17     1  0  0
# E24     2  0  0
# E25     2  0  0
# E31     1  0  0
# E33     2  0  0
# E34     1  0  0
# E36     1  0  0
# E38     1  0  0
# E40     1  0  0
# E44     2  0  0
# E46     1  0  0
# E49     1  0  0
# E50     1  0  0
# E58     1  0  0
# E63     1  0  0
# E67     2  0  0
# E68     1  0  0
# E77     0  1  0
# E8      2  0  0
# F E69   0  0  1
# F G63   0  0  1
# ...

# %%
train['Cabin'] = train.groupby(['Pclass'])['Cabin'].apply(lambda x: x.fillna('G6'))

# %%
train['Cabin'].isnull().sum()
# Out:
# 0

# %%
train.isnull().sum
# Out:
# <bound method DataFrame.sum of      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False  False  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
# Table of survival vs. sex
survived_sex = pd.crosstab(index=train["Survived"], 
                           columns=train["Sex"])

survived_sex.index= ["died","survived"]

survived_sex
# Out:
# Sex       female  male
# died          81   468
# survived     233   109

# %%
test=pd.read_csv("test.csv")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
title=pd.DataFrame(test['Name'])
title=[i.split()[1] for i in test['Name']]

# %%
train=train.drop(['Name'],axis=1)

# %%
test['Title']=title

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500    G6        S    Mr.
# 1          PC 17599  71.2833   C85        C   Mrs.
# 2  STON/O2. 3101282   7.9250    G6        S  Miss.
# 3            113803  53.1000  C123        S   Mrs.
# 4            373450   8.0500    G6        S    Mr.

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title
# 0  34.5      0      0   330911   7.8292   NaN        Q   Mr.
# 1  47.0      1      0   363272   7.0000   NaN        S  Mrs.
# 2  62.0      0      0   240276   9.6875   NaN        Q   Mr.
# 3  27.0      0      0   315154   8.6625   NaN        S   Mr.
# 4  22.0      1      1  3101298  12.2875   NaN        S  Mrs.

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
##test['Age']=test.groupby(['Title'])['Age'].apply(lambda x: x.fillna(x.mean()))
test['Age']=test.groupby(['Title'])['Age'].apply(lambda x: x.fillna(x.mean()))

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              1
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
test.groupby(['Title'])['Age'].apply(lambda x: x.isnull().sum())
# Out:
# Title
# Billiard,       0
# Brito,          0
# Carlo,          0
# Col.            0
# Dr.             0
# Khalil,         0
# Master.         0
# Messemaeker,    0
# Miss.           0
# Mr.             0
# Mrs.            0
# Ms.             1
# Palmquist,      0
# Planke,         0
# Rev.            0
# y               0
# Name: Age, dtype: int64

# %%
##train['Age'].fillna(value=train['Age'].mean() , inplace=True)
test['Age'].fillna(value=test['Age'].mean(),inplace=True)

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
test['Cabin'].value_counts()
# Out:
# B57 B59 B63 B66    3
# C23 C25 C27        2
# C116               2
# C78                2
# E34                2
# C80                2
# C6                 2
# C89                2
# C31                2
# A34                2
# B45                2
# C55 C57            2
# C101               2
# F4                 2
# E39 E41            1
# C105               1
# B69                1
# D21                1
# A9                 1
# C62 C64            1
# B26                1
# B10                1
# D38                1
# D15                1
# B36                1
# D22                1
# A21                1
# B51 B53 B55        1
# D30                1
# D37                1
#                   ..
# F E46              1
# F33                1
# E31                1
# C46                1
# C32                1
# A29                1
# B71                1
# C85                1
# C54                1
# C106               1
# B61                1
# C51                1
# ...

# %%
test['Fare'].fillna(value=test['Fare'],inplace=True)

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
test.groupby(['Pclass'])['Cabin'].value_counts()
# Out:
# Pclass  Cabin
# 1       B57 B59 B63 B66    3
#         A34                2
#         B45                2
#         C101               2
#         C116               2
#         C23 C25 C27        2
#         C31                2
#         C55 C57            2
#         C6                 2
#         C78                2
#         C80                2
#         C89                2
#         E34                2
#         A11                1
#         A18                1
#         A21                1
#         A29                1
#         A9                 1
#         B10                1
#         B11                1
#         B24                1
#         B26                1
#         B36                1
#         B41                1
#         B51 B53 B55        1
#         B52 B54 B56        1
#         B58 B60            1
#         B61                1
#         B69                1
#         B71                1
#                           ..
# ...

# %%
test.groupby(['Pclass'])['Cabin'].apply(lambda x: x.isnull().sum())
# Out:
# Pclass
# 1     27
# 2     86
# 3    214
# Name: Cabin, dtype: int64

# %%
pd.crosstab(test["Cabin"],test["Pclass"])
# Out:
# Pclass           1  2  3
# Cabin
# A11              1  0  0
# A18              1  0  0
# A21              1  0  0
# A29              1  0  0
# A34              2  0  0
# A9               1  0  0
# B10              1  0  0
# B11              1  0  0
# B24              1  0  0
# B26              1  0  0
# B36              1  0  0
# B41              1  0  0
# B45              2  0  0
# B51 B53 B55      1  0  0
# B52 B54 B56      1  0  0
# B57 B59 B63 B66  3  0  0
# B58 B60          1  0  0
# B61              1  0  0
# B69              1  0  0
# B71              1  0  0
# B78              1  0  0
# C101             2  0  0
# C105             1  0  0
# C106             1  0  0
# C116             2  0  0
# C130             1  0  0
# C132             1  0  0
# C22 C26          1  0  0
# C23 C25 C27      2  0  0
# C28              1  0  0
# ...             .. .. ..
# C97              1  0  0
# D                0  1  0
# D10 D12          1  0  0
# D15              1  0  0
# ...

# %%
test['Cabin'] = test.groupby(['Pclass'])['Cabin'].apply(lambda x: x.fillna(test['Cabin'].value_counts().idxmax()))

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Cabin          0
# Embarked       0
# Title          0
# dtype: int64

# %%
test.groupby(['Cabin'])['Fare'].apply(lambda x: x.isnull().sum())
# Out:
# Cabin
# A11                0
# A18                0
# A21                0
# A29                0
# A34                0
# A9                 0
# B10                0
# B11                0
# B24                0
# B26                0
# B36                0
# B41                0
# B45                0
# B51 B53 B55        0
# B52 B54 B56        0
# B57 B59 B63 B66    1
# B58 B60            0
# B61                0
# B69                0
# B71                0
# B78                0
# C101               0
# C105               0
# C106               0
# C116               0
# C130               0
# C132               0
# C22 C26            0
# C23 C25 C27        0
# C28                0
#                   ..
# C97                0
# D                  0
# D10 D12            0
# D15                0
# D19                0
# D21                0
# D22                0
# D28                0
# D30                0
# D34                0
# D37                0
# D38                0
# ...

# %%
##test1=test[(test['Cabin']=='B57 B59 B63 B66')]

# %%
##test1.groupby(['Cabin'])['Fare'].value_counts()

# %%
test['Fare'].fillna(test1['Fare'].value_counts().idxmax(),inplace=True)

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Title          0
# dtype: int64

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare            Cabin Embarked Title
# 0  34.5      0      0   330911   7.8292  B57 B59 B63 B66        Q   Mr.
# 1  47.0      1      0   363272   7.0000  B57 B59 B63 B66        S  Mrs.
# 2  62.0      0      0   240276   9.6875  B57 B59 B63 B66        Q   Mr.
# 3  27.0      0      0   315154   8.6625  B57 B59 B63 B66        S   Mr.
# 4  22.0      1      1  3101298  12.2875  B57 B59 B63 B66        S  Mrs.

# %%
train['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.groupby(['Pclass'])['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
##data=train.append(test)

# %%
train1=train.drop(['Ticket','Cabin','Title'],axis=1)
test1=test.drop(['Ticket','Cabin','Title'],axis=1)

# %%
train1=train1.drop(['Embarked'],axis=1)
test1=test1.drop(['Embarked'],axis=1)

# %%
train1.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500

# %%
test1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare
# 0  34.5      0      0   7.8292
# 1  47.0      1      0   7.0000
# 2  62.0      0      0   9.6875
# 3  27.0      0      0   8.6625
# 4  22.0      1      1  12.2875

# %%
test1=test1.drop(['Name'],axis=1)
test1.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare
# 0          892       3    male  34.5      0      0   7.8292
# 1          893       3  female  47.0      1      0   7.0000
# 2          894       2    male  62.0      0      0   9.6875
# 3          895       3    male  27.0      0      0   8.6625
# 4          896       3  female  22.0      1      1  12.2875

# %%
combine=(train1,test1)

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'male': 0, 'female': 1} ).astype(int)

train1.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    0  22.0      1      0   7.2500
# 1            2         1       1    1  38.0      1      0  71.2833
# 2            3         1       3    1  26.0      0      0   7.9250
# 3            4         1       1    1  35.0      1      0  53.1000
# 4            5         0       3    0  35.0      0      0   8.0500

# %%
X_train = train1.drop("Survived", axis=1)
Y_train = train1["Survived"]
X_test  = test1
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 7), (891,), (418, 7))

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()
logit.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
Y_pred = logit.predict(X_test)

# %%
acc_log = logit.score(X_train, Y_train) 
acc_log
# Out:
# 0.8013468013468014

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": Y_pred
    })

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
submission.to_csv('submission.csv', index=False)
